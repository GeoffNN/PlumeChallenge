# %%
import pandas as pd

# %%
table = pd.read_csv('X_train.csv', nrows=None)

# %%
table.shape
# Out:
# (448169, 33)

# %%
pd.set_option('display.max_columns',33)

# %%
print(table[:5])
# Out:
#    ID  hlres_50  green_5000   hldres_50  daytime  route_100  precipintensity  \
# 0   0       NaN   5172542.5  3755.19043     72.0        NaN           0.6096
# 1   1       NaN   5172542.5  3755.19043     72.0        NaN           0.6096
# 2   2       NaN   5172542.5  3755.19043     73.0        NaN           0.0965
# 3   3       NaN   5172542.5  3755.19043     73.0        NaN           0.0965
# 4   4       NaN   5172542.5  3755.19043     74.0        NaN           0.0000
#
#    precipprobability  hlres_1000  temperature is_calmday   route_1000  \
# 0               0.61         NaN         9.49      False  8027.166504
# 1               0.61         NaN         9.49      False  8027.166504
# 2               0.14         NaN         8.22      False  8027.166504
# 3               0.14         NaN         8.22      False  8027.166504
# 4               0.00         NaN         7.58      False  8027.166504
#
#    roadinvdist  port_5000  windbearingsin  cloudcover    hldres_100  \
# ...

# %%
table.describe()
# Out:
#                   ID      hlres_50    green_5000      hldres_50  \
# count  448169.000000  69184.000000  3.790340e+05  227708.000000
# mean   224084.000000   6623.680958  6.877821e+06    6901.928677
# std    129375.390734   2203.285162  4.154899e+06    1762.396326
# min         0.000000   2217.580322  2.024936e+06    2217.580322
# 25%    112042.000000   7725.424805  3.664739e+06    7725.424805
# 50%    224084.000000   7725.424805  5.904352e+06    7725.424805
# 75%    336126.000000   7725.425293  1.009155e+07    7725.424805
# max    448168.000000   7725.425293  1.992367e+07    7725.425293
#
#              daytime     route_100  precipintensity  precipprobability  \
# count  448169.000000  70159.000000    448169.000000      448169.000000
# mean     7119.975188    257.656625         0.091553           0.084999
# std      4098.101103    133.189196         0.315952           0.188865
# min         0.000000    127.500359         0.000000           0.000000
# ...

# %%
table.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 448169 entries, 0 to 448168
# Data columns (total 33 columns):
# ID                   448169 non-null int64
# hlres_50             69184 non-null float64
# green_5000           379034 non-null float64
# hldres_50            227708 non-null float64
# daytime              448169 non-null float64
# route_100            70159 non-null float64
# precipintensity      448169 non-null float64
# precipprobability    448169 non-null float64
# hlres_1000           363629 non-null float64
# temperature          448169 non-null float64
# is_calmday           448169 non-null bool
# route_1000           448169 non-null float64
# roadinvdist          448169 non-null float64
# port_5000            224286 non-null float64
# windbearingsin       448169 non-null float64
# cloudcover           448169 non-null float64
# hldres_100           308875 non-null float64
# natural_5000         305050 non-null float64
# ...

# %%
# goal 1 : plot the stations by station_id
